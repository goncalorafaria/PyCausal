# %%
from pycausal import *
import matplotlib.pyplot as plt

# %%
### initial t

scm = SCM("Study Graph")
rv = placeholder("Causality for Machine Learning")

rvs = [ placeholder(i) for i in ["Causality for Machine Learning","Elements of Causal Inference", "A Meta-Transfer Objective for Learning to disentangle causal Mechanisms"] ]

rl = ["Bandits with unobserved confounders", "Independently cotrollable features","Woulda, coulda, shoulda", "causal reasoning from meta-reinforcemente learning","evaluating rl algorithms in observational health settings","deconfounding rl in observational setting","near optimal rl in dynamic treatment regimes"]
rl = ["RL:"+i for i in rl]

great=["Optimal decision making under strategic behavior", "Counterfactual reasoning and learning systems: the example of computacional advertasing","A survey of learning causality with data","Modeling confounding by half-sibling regression"]
see = []
other = []
snrvs = [ square(rvs[0]).mark(n) for n in (rl+great+see+other) ]

# %%
#plt.figure( figsize=(8,8) )
scm.draw(figsize=(15,15), node_size=10000)
